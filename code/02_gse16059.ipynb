# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

import kraft

# %%
SETTING = kraft.json.read("setting.json")

# %% [markdown]
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE16059

# %%
_x_samples = kraft.geo.get_gse(
    "GSE16059", SETTING["data_directory_path"], overwrite=SETTING["overwrite"]
)
# Out:
# /media/kwat/CarrotCake/garden/data/chronic_fatigue_syndrome//GSE16059_family.soft.gz exists.
# --------------------------------------------------------------------------------
#                            PBLs_pair 228340_unaffected    PBLs_pair 228340_CFS
# Feature
# Sample_geo_accession                         GSM402241               GSM402242
# Sample_status                    Public on May 12 2009   Public on May 12 2009
# Sample_submission_date                     May 12 2009             May 12 2009
# Sample_last_update_date                    May 12 2009             May 12 2009
# Sample_type                                        RNA                     RNA
# Sample_channel_count                                 1                       1
# Sample_source_name_ch1   PBLs, pair 228340, unaffected  PBLs, pair 228340, CFS
# Sample_organism_ch1                       Homo sapiens            Homo sapiens
# (31, 88)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
#                         PBLs_pair 228340_unaffected  PBLs_pair 228340_CFS
# Feature
# diagnonsis: unaffected                            1                     0
# diagnonsis: CFS                                   0                     1
# diagnonsis: ICF                                   0                     0
# (3, 88)
# --------------------------------------------------------------------------------
#
#
# GPL570
# GB_ACC
# SPOT_ID
# Species Scientific Name
# Annotation Date
# Sequence Type
# Sequence Source
# Target Description
# Representative Public ID
# Gene Title
# > Gene Symbol <
# ENTREZ_GENE_ID
# RefSeq Transcript ID
# Gene Ontology Biological Process
# Gene Ontology Cellular Component
# Gene Ontology Molecular Function
# 54675 keys ==> 22881 unique values
# (54675, 88)
# Collapsing...
# (22880, 88)
# --------------------------------------------------------------------------------
#           PBLs_pair 228340_unaffected  PBLs_pair 228340_CFS
# Gene
# A1BG                             5.22                 4.290
# A1BG-AS1                         4.58                 4.780
# A1CF                             5.33                 5.370
# A2M                              5.18                 4.730
# A2M-AS1                          6.03                 6.100
# A2ML1                            4.86                 5.485
# A2MP1                            3.85                 3.880
# A4GALT                           4.50                 4.340
# (22880, 88)
# --------------------------------------------------------------------------------

# %%
binary_feature_x_sample = _x_samples[2]

binary_feature_x_sample
# Out:
#                         PBLs_pair 228340_unaffected  PBLs_pair 228340_CFS  \
# Feature
# diagnonsis: unaffected                            1                     0
# diagnonsis: CFS                                   0                     1
# diagnonsis: ICF                                   0                     0
#
#                         PBLs_pair 220263_unaffected  PBLs_pair 220263_CFS  \
# Feature
# diagnonsis: unaffected                            1                     0
# diagnonsis: CFS                                   0                     1
# diagnonsis: ICF                                   0                     0
#
#                         PBLs_pair 235495_unaffected  PBLs_pair 235495_ICF  \
# Feature
# diagnonsis: unaffected                            1                     0
# diagnonsis: CFS                                   0                     0
# diagnonsis: ICF                                   0                     1
#
#                         PBLs_pair 227565_unaffected  PBLs_pair 227565_ICF  \
# Feature
# diagnonsis: unaffected                            1                     0
# diagnonsis: CFS                                   0                     0
# diagnonsis: ICF                                   0                     1
#
#                         PBLs_pair 232496_CFS  PBLs_pair 232496_unaffected  \
# Feature
# diagnonsis: unaffected                     0                            1
# diagnonsis: CFS                            1                            0
# diagnonsis: ICF                            0                            0
#
#                         ...  PBLs_pair 218156_CFS  \
# Feature                 ...
# diagnonsis: unaffected  ...                     0
# diagnonsis: CFS         ...                     1
# diagnonsis: ICF         ...                     0
#
#                         PBLs_pair 218156_unaffected  PBLs_pair 33004_CFS  \
# Feature
# diagnonsis: unaffected                            1                    0
# diagnonsis: CFS                                   0                    1
# diagnonsis: ICF                                   0                    0
#
#                         PBLs_pair 33004_unaffected  PBLs_pair 253644_CFS  \
# Feature
# diagnonsis: unaffected                           1                     0
# diagnonsis: CFS                                  0                     1
# diagnonsis: ICF                                  0                     0
#
#                         PBLs_pair 253644_unaffected  \
# Feature
# diagnonsis: unaffected                            1
# diagnonsis: CFS                                   0
# diagnonsis: ICF                                   0
#
#                         PBLs_pair 236175_unaffected  PBLs_pair 236175_CFS  \
# Feature
# diagnonsis: unaffected                            1                     0
# diagnonsis: CFS                                   0                     1
# diagnonsis: ICF                                   0                     0
#
#                         PBLs_pair 48695_ICF  PBLs_pair 48695_unaffected
# Feature
# diagnonsis: unaffected                    0                           1
# diagnonsis: CFS                           0                           0
# diagnonsis: ICF                           1                           0
#
# [3 rows x 88 columns]

# %%
gene_x_sample = _x_samples[3]

gene_x_sample
# Out:
#               PBLs_pair 228340_unaffected  PBLs_pair 228340_CFS  \
# Gene
# A1BG                                5.220                 4.290
# A1BG-AS1                            4.580                 4.780
# A1CF                                5.330                 5.370
# A2M                                 5.180                 4.730
# A2M-AS1                             6.030                 6.100
# ...                                   ...                   ...
# ZZZ3                                4.205                 4.665
# abParts                             6.660                 5.870
# av27s1                              4.630                 4.910
# hsa-let-7a-3                        5.120                 4.930
# mir-223                             4.650                 4.300
#
#               PBLs_pair 220263_unaffected  PBLs_pair 220263_CFS  \
# Gene
# A1BG                                4.070                 3.800
# A1BG-AS1                            4.660                 4.800
# A1CF                                5.340                 5.050
# A2M                                 4.430                 4.550
# A2M-AS1                             5.590                 5.650
# ...                                   ...                   ...
# ZZZ3                                4.205                 4.475
# abParts                             5.590                 5.760
# av27s1                              4.730                 4.730
# hsa-let-7a-3                        4.615                 5.245
# mir-223                             3.900                 4.390
#
#               PBLs_pair 235495_unaffected  PBLs_pair 235495_ICF  \
# Gene
# A1BG                                3.630                 4.020
# A1BG-AS1                            4.810                 5.090
# A1CF                                5.010                 5.240
# A2M                                 4.995                 4.495
# A2M-AS1                             5.690                 5.730
# ...                                   ...                   ...
# ZZZ3                                4.695                 4.615
# abParts                             5.620                 5.570
# av27s1                              4.940                 4.750
# hsa-let-7a-3                        4.995                 4.800
# mir-223                             3.900                 4.070
#
#               PBLs_pair 227565_unaffected  PBLs_pair 227565_ICF  \
# Gene
# A1BG                                3.850                 3.970
# A1BG-AS1                            4.870                 5.270
# A1CF                                5.020                 5.120
# A2M                                 4.960                 4.815
# A2M-AS1                             5.750                 5.510
# ...                                   ...                   ...
# ZZZ3                                4.350                 4.030
# abParts                             5.800                 5.690
# av27s1                              4.930                 4.750
# hsa-let-7a-3                        4.855                 4.800
# mir-223                             4.390                 4.260
#
#               PBLs_pair 232496_CFS  PBLs_pair 232496_unaffected  ...  \
# Gene                                                             ...
# A1BG                         4.390                        4.130  ...
# A1BG-AS1                     4.920                        5.130  ...
# A1CF                         5.635                        5.125  ...
# A2M                          4.760                        4.740  ...
# A2M-AS1                      5.790                        5.760  ...
# ...                            ...                          ...  ...
# ZZZ3                         4.590                        4.165  ...
# abParts                      5.980                        5.230  ...
# av27s1                       5.430                        4.900  ...
# hsa-let-7a-3                 5.090                        4.840  ...
# mir-223                      4.720                        4.010  ...
#
#               PBLs_pair 218156_CFS  PBLs_pair 218156_unaffected  \
# Gene
# A1BG                         4.480                        4.100
# A1BG-AS1                     4.700                        4.650
# A1CF                         5.045                        4.900
# A2M                          4.275                        4.410
# A2M-AS1                      5.500                        5.650
# ...                            ...                          ...
# ZZZ3                         4.060                        3.900
# abParts                      5.690                        5.540
# av27s1                       4.810                        4.820
# hsa-let-7a-3                 4.835                        4.725
# mir-223                      4.240                        4.010
#
#               PBLs_pair 33004_CFS  PBLs_pair 33004_unaffected  \
# Gene
# A1BG                        4.610                       4.740
# A1BG-AS1                    4.710                       4.670
# A1CF                        4.885                       4.880
# A2M                         4.385                       4.355
# A2M-AS1                     5.510                       5.700
# ...                           ...                         ...
# ZZZ3                        4.420                       4.360
# abParts                     5.830                       5.660
# av27s1                      4.980                       4.800
# hsa-let-7a-3                5.160                       4.890
# mir-223                     3.720                       3.760
#
#               PBLs_pair 253644_CFS  PBLs_pair 253644_unaffected  \
# Gene
# A1BG                          3.83                        4.570
# A1BG-AS1                      4.15                        3.760
# A1CF                          4.76                        4.980
# A2M                           4.51                        4.505
# A2M-AS1                       5.83                        5.770
# ...                            ...                          ...
# ZZZ3                          4.11                        4.050
# abParts                       5.45                        5.230
# av27s1                        4.79                        4.770
# hsa-let-7a-3                  4.79                        4.815
# mir-223                       4.08                        4.110
#
#               PBLs_pair 236175_unaffected  PBLs_pair 236175_CFS  \
# Gene
# A1BG                                4.800                 3.960
# A1BG-AS1                            4.540                 4.230
# A1CF                                5.160                 4.915
# A2M                                 4.595                 4.750
# A2M-AS1                             5.900                 5.730
# ...                                   ...                   ...
# ZZZ3                                4.530                 4.335
# abParts                             5.560                 5.490
# av27s1                              4.930                 4.700
# hsa-let-7a-3                        5.130                 4.740
# mir-223                             4.430                 4.150
#
#               PBLs_pair 48695_ICF  PBLs_pair 48695_unaffected
# Gene
# A1BG                        4.450                       4.180
# A1BG-AS1                    4.190                       4.160
# A1CF                        5.055                       4.925
# A2M                         4.515                       4.515
# A2M-AS1                     5.840                       5.690
# ...                           ...                         ...
# ZZZ3                        4.230                       4.395
# abParts                     5.590                       5.760
# av27s1                      4.820                       4.740
# hsa-let-7a-3                4.715                       4.735
# mir-223                     4.170                       4.140
#
# [22880 rows x 88 columns]
