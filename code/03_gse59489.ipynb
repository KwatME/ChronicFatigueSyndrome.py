# %% [markdown]
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE59489

# %%
from __init__ import *

# %%
gse_id = "GSE59489"

# %%
path_template = "{}{}_{{}}_x_sample.tsv".format(SETTING["directory_path"], gse_id)

# %%
_x_sample_ = kraft.geo.get_gse(
    gse_id, SETTING["directory_path"], overwrite=SETTING["overwrite"]
)
# Out:
# /media/kwat/CarrotCake/garden/data/chronic_fatigue_syndrome/GSE59489_family.soft.gz exists.
# PLATFORM = GPL13534
# SAMPLE = GSM1437759
# SAMPLE = GSM1437760
# SAMPLE = GSM1437761
# SAMPLE = GSM1437762
# SAMPLE = GSM1437763
# SAMPLE = GSM1437764
# SAMPLE = GSM1437765
# SAMPLE = GSM1437766
# SAMPLE = GSM1437767
# SAMPLE = GSM1437768
# SAMPLE = GSM1437769
# SAMPLE = GSM1437770
# SAMPLE = GSM1437771
# SAMPLE = GSM1437772
# SAMPLE = GSM1437773
# SAMPLE = GSM1437774
# SAMPLE = GSM1437775
# SAMPLE = GSM1437776
# SAMPLE = GSM1437777
# SAMPLE = GSM1437778
# SAMPLE = GSM1437779
# SAMPLE = GSM1437780
# SAMPLE = GSM1437781
# SAMPLE = GSM1437782
# --------------------------------------------------------------------------------
#                         PBMC genomic DNA_CFS1  PBMC genomic DNA_CFS2
# Feature
# Sample_title            PBMC genomic DNA_CFS1  PBMC genomic DNA_CFS2
# Sample_geo_accession               GSM1437759             GSM1437760
# Sample_status           Public on Aug 12 2014  Public on Aug 12 2014
# Sample_submission_date            Jul 16 2014            Jul 16 2014
# (40, 24)
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#                           PBMC genomic DNA_CFS1  PBMC genomic DNA_CFS2
# Feature (binary)
# subject id.CFS subject 1                      1                      0
# subject id.CFS subject 2                      0                      1
# subject id.CFS subject 3                      0                      0
# subject id.CFS subject 4                      0                      0
# (26, 24)
# --------------------------------------------------------------------------------
# GPL13534
# Name
# AddressA_ID
# AlleleA_ProbeSeq
# AddressB_ID
# AlleleB_ProbeSeq
# Infinium_Design_Type
# Next_Base
# Color_Channel
# Forward_Sequence
# Genome_Build
# CHR
# MAPINFO
# SourceSeq
# Chromosome_36
# Coordinate_36
# Strand
# Probe_SNPs
# Probe_SNPs_10
# Random_Loci
# Methyl27_Loci
# >> UCSC_RefGene_Name <<
# UCSC_RefGene_Accession
# UCSC_RefGene_Group
# UCSC_CpG_Islands_Name
# Relation_to_UCSC_CpG_Island
# Phantom
# DMR
# Enhancer
# HMM_Island
# Regulatory_Feature_Name
# Regulatory_Feature_Group
# DHS
# RANGE_START
# RANGE_END
# RANGE_GB
# SPOT_ID
# 485577 key => 20618 unique value
# Named 353316/485577 (72.76%)
# (485577, 24)
# Collapsing...
# (18674, 24)
# --------------------------------------------------------------------------------
#           PBMC genomic DNA_CFS1  PBMC genomic DNA_CFS2
# Gene
# A1BG                   0.606930               0.517600
# A1BG-AS1               0.322765               0.299545
# A1CF                   0.838470               0.829080
# A2M                    0.451520               0.500430
# (18674, 24)
# --------------------------------------------------------------------------------

# %%
binary_feature_x_sample = _x_sample_[2]

binary_feature_x_sample.to_csv(path_template.format("binary_feature"), sep="\t")

binary_feature_x_sample
# Out:
#                                               PBMC genomic DNA_CFS1  \
# Feature (binary)
# subject id.CFS subject 1                                          1
# subject id.CFS subject 2                                          0
# subject id.CFS subject 3                                          0
# subject id.CFS subject 4                                          0
# subject id.CFS subject 5                                          0
# subject id.CFS subject 6                                          0
# subject id.Control subject 1                                      0
# subject id.Control subject 2                                      0
# subject id.Control subject 3                                      0
# subject id.Control subject 4                                      0
# subject id.Control subject 5                                      0
# subject id.Control subject 6                                      0
# subject id.CFS subject 7                                          0
# subject id.CFS subject 8                                          0
# subject id.CFS subject 9                                          0
# subject id.CFS subject 10                                         0
# subject id.CFS subject 11                                         0
# subject id.CFS subject 12                                         0
# subject id.Control subject 7                                      0
# subject id.Control subject 8                                      0
# subject id.Control subject 9                                      0
# subject id.Control subject 10                                     0
# subject id.Control subject 11                                     0
# subject id.Control subject 12                                     0
# disease state.Chronic Fatigue Syndrome (CFS)                      1
# disease state.Control                                             0
#
#                                               PBMC genomic DNA_CFS2  \
# Feature (binary)
# subject id.CFS subject 1                                          0
# subject id.CFS subject 2                                          1
# subject id.CFS subject 3                                          0
# subject id.CFS subject 4                                          0
# subject id.CFS subject 5                                          0
# subject id.CFS subject 6                                          0
# subject id.Control subject 1                                      0
# subject id.Control subject 2                                      0
# subject id.Control subject 3                                      0
# subject id.Control subject 4                                      0
# subject id.Control subject 5                                      0
# subject id.Control subject 6                                      0
# subject id.CFS subject 7                                          0
# subject id.CFS subject 8                                          0
# subject id.CFS subject 9                                          0
# subject id.CFS subject 10                                         0
# subject id.CFS subject 11                                         0
# subject id.CFS subject 12                                         0
# subject id.Control subject 7                                      0
# subject id.Control subject 8                                      0
# subject id.Control subject 9                                      0
# subject id.Control subject 10                                     0
# subject id.Control subject 11                                     0
# subject id.Control subject 12                                     0
# disease state.Chronic Fatigue Syndrome (CFS)                      1
# disease state.Control                                             0
#
#                                               PBMC genomic DNA_CFS3  \
# Feature (binary)
# subject id.CFS subject 1                                          0
# subject id.CFS subject 2                                          0
# subject id.CFS subject 3                                          1
# subject id.CFS subject 4                                          0
# subject id.CFS subject 5                                          0
# subject id.CFS subject 6                                          0
# subject id.Control subject 1                                      0
# subject id.Control subject 2                                      0
# subject id.Control subject 3                                      0
# subject id.Control subject 4                                      0
# subject id.Control subject 5                                      0
# subject id.Control subject 6                                      0
# subject id.CFS subject 7                                          0
# subject id.CFS subject 8                                          0
# subject id.CFS subject 9                                          0
# subject id.CFS subject 10                                         0
# subject id.CFS subject 11                                         0
# subject id.CFS subject 12                                         0
# subject id.Control subject 7                                      0
# subject id.Control subject 8                                      0
# subject id.Control subject 9                                      0
# subject id.Control subject 10                                     0
# subject id.Control subject 11                                     0
# subject id.Control subject 12                                     0
# disease state.Chronic Fatigue Syndrome (CFS)                      1
# disease state.Control                                             0
#
#                                               PBMC genomic DNA_CFS4  \
# Feature (binary)
# subject id.CFS subject 1                                          0
# subject id.CFS subject 2                                          0
# subject id.CFS subject 3                                          0
# subject id.CFS subject 4                                          1
# subject id.CFS subject 5                                          0
# subject id.CFS subject 6                                          0
# subject id.Control subject 1                                      0
# subject id.Control subject 2                                      0
# subject id.Control subject 3                                      0
# subject id.Control subject 4                                      0
# subject id.Control subject 5                                      0
# subject id.Control subject 6                                      0
# subject id.CFS subject 7                                          0
# subject id.CFS subject 8                                          0
# subject id.CFS subject 9                                          0
# subject id.CFS subject 10                                         0
# subject id.CFS subject 11                                         0
# subject id.CFS subject 12                                         0
# subject id.Control subject 7                                      0
# subject id.Control subject 8                                      0
# subject id.Control subject 9                                      0
# subject id.Control subject 10                                     0
# subject id.Control subject 11                                     0
# subject id.Control subject 12                                     0
# disease state.Chronic Fatigue Syndrome (CFS)                      1
# disease state.Control                                             0
#
#                                               PBMC genomic DNA_CFS5  \
# Feature (binary)
# subject id.CFS subject 1                                          0
# subject id.CFS subject 2                                          0
# subject id.CFS subject 3                                          0
# subject id.CFS subject 4                                          0
# subject id.CFS subject 5                                          1
# subject id.CFS subject 6                                          0
# subject id.Control subject 1                                      0
# subject id.Control subject 2                                      0
# subject id.Control subject 3                                      0
# subject id.Control subject 4                                      0
# subject id.Control subject 5                                      0
# subject id.Control subject 6                                      0
# subject id.CFS subject 7                                          0
# subject id.CFS subject 8                                          0
# subject id.CFS subject 9                                          0
# subject id.CFS subject 10                                         0
# subject id.CFS subject 11                                         0
# subject id.CFS subject 12                                         0
# subject id.Control subject 7                                      0
# subject id.Control subject 8                                      0
# subject id.Control subject 9                                      0
# subject id.Control subject 10                                     0
# subject id.Control subject 11                                     0
# subject id.Control subject 12                                     0
# disease state.Chronic Fatigue Syndrome (CFS)                      1
# disease state.Control                                             0
#
#                                               PBMC genomic DNA_CFS6  \
# Feature (binary)
# subject id.CFS subject 1                                          0
# subject id.CFS subject 2                                          0
# subject id.CFS subject 3                                          0
# subject id.CFS subject 4                                          0
# subject id.CFS subject 5                                          0
# subject id.CFS subject 6                                          1
# subject id.Control subject 1                                      0
# subject id.Control subject 2                                      0
# subject id.Control subject 3                                      0
# subject id.Control subject 4                                      0
# subject id.Control subject 5                                      0
# subject id.Control subject 6                                      0
# subject id.CFS subject 7                                          0
# subject id.CFS subject 8                                          0
# subject id.CFS subject 9                                          0
# subject id.CFS subject 10                                         0
# subject id.CFS subject 11                                         0
# subject id.CFS subject 12                                         0
# subject id.Control subject 7                                      0
# subject id.Control subject 8                                      0
# subject id.Control subject 9                                      0
# subject id.Control subject 10                                     0
# subject id.Control subject 11                                     0
# subject id.Control subject 12                                     0
# disease state.Chronic Fatigue Syndrome (CFS)                      1
# disease state.Control                                             0
#
#                                               PBMC genomic DNA_Control1  \
# Feature (binary)
# subject id.CFS subject 1                                              0
# subject id.CFS subject 2                                              0
# subject id.CFS subject 3                                              0
# subject id.CFS subject 4                                              0
# subject id.CFS subject 5                                              0
# subject id.CFS subject 6                                              0
# subject id.Control subject 1                                          1
# subject id.Control subject 2                                          0
# subject id.Control subject 3                                          0
# subject id.Control subject 4                                          0
# subject id.Control subject 5                                          0
# subject id.Control subject 6                                          0
# subject id.CFS subject 7                                              0
# subject id.CFS subject 8                                              0
# subject id.CFS subject 9                                              0
# subject id.CFS subject 10                                             0
# subject id.CFS subject 11                                             0
# subject id.CFS subject 12                                             0
# subject id.Control subject 7                                          0
# subject id.Control subject 8                                          0
# subject id.Control subject 9                                          0
# subject id.Control subject 10                                         0
# subject id.Control subject 11                                         0
# subject id.Control subject 12                                         0
# disease state.Chronic Fatigue Syndrome (CFS)                          0
# disease state.Control                                                 1
#
#                                               PBMC genomic DNA_Control2  \
# Feature (binary)
# subject id.CFS subject 1                                              0
# subject id.CFS subject 2                                              0
# subject id.CFS subject 3                                              0
# subject id.CFS subject 4                                              0
# subject id.CFS subject 5                                              0
# subject id.CFS subject 6                                              0
# subject id.Control subject 1                                          0
# subject id.Control subject 2                                          1
# subject id.Control subject 3                                          0
# subject id.Control subject 4                                          0
# subject id.Control subject 5                                          0
# subject id.Control subject 6                                          0
# subject id.CFS subject 7                                              0
# subject id.CFS subject 8                                              0
# subject id.CFS subject 9                                              0
# subject id.CFS subject 10                                             0
# subject id.CFS subject 11                                             0
# subject id.CFS subject 12                                             0
# subject id.Control subject 7                                          0
# subject id.Control subject 8                                          0
# subject id.Control subject 9                                          0
# subject id.Control subject 10                                         0
# subject id.Control subject 11                                         0
# subject id.Control subject 12                                         0
# disease state.Chronic Fatigue Syndrome (CFS)                          0
# disease state.Control                                                 1
#
#                                               PBMC genomic DNA_Control3  \
# Feature (binary)
# subject id.CFS subject 1                                              0
# subject id.CFS subject 2                                              0
# subject id.CFS subject 3                                              0
# subject id.CFS subject 4                                              0
# subject id.CFS subject 5                                              0
# subject id.CFS subject 6                                              0
# subject id.Control subject 1                                          0
# subject id.Control subject 2                                          0
# subject id.Control subject 3                                          1
# subject id.Control subject 4                                          0
# subject id.Control subject 5                                          0
# subject id.Control subject 6                                          0
# subject id.CFS subject 7                                              0
# subject id.CFS subject 8                                              0
# subject id.CFS subject 9                                              0
# subject id.CFS subject 10                                             0
# subject id.CFS subject 11                                             0
# subject id.CFS subject 12                                             0
# subject id.Control subject 7                                          0
# subject id.Control subject 8                                          0
# subject id.Control subject 9                                          0
# subject id.Control subject 10                                         0
# subject id.Control subject 11                                         0
# subject id.Control subject 12                                         0
# disease state.Chronic Fatigue Syndrome (CFS)                          0
# disease state.Control                                                 1
#
#                                               PBMC genomic DNA_Control4  ...  \
# Feature (binary)                                                         ...
# subject id.CFS subject 1                                              0  ...
# subject id.CFS subject 2                                              0  ...
# subject id.CFS subject 3                                              0  ...
# subject id.CFS subject 4                                              0  ...
# subject id.CFS subject 5                                              0  ...
# subject id.CFS subject 6                                              0  ...
# subject id.Control subject 1                                          0  ...
# subject id.Control subject 2                                          0  ...
# subject id.Control subject 3                                          0  ...
# subject id.Control subject 4                                          1  ...
# subject id.Control subject 5                                          0  ...
# subject id.Control subject 6                                          0  ...
# subject id.CFS subject 7                                              0  ...
# subject id.CFS subject 8                                              0  ...
# subject id.CFS subject 9                                              0  ...
# subject id.CFS subject 10                                             0  ...
# subject id.CFS subject 11                                             0  ...
# subject id.CFS subject 12                                             0  ...
# subject id.Control subject 7                                          0  ...
# subject id.Control subject 8                                          0  ...
# subject id.Control subject 9                                          0  ...
# subject id.Control subject 10                                         0  ...
# subject id.Control subject 11                                         0  ...
# subject id.Control subject 12                                         0  ...
# disease state.Chronic Fatigue Syndrome (CFS)                          0  ...
# disease state.Control                                                 1  ...
#
#                                               PBMC genomic DNA_CFS9  \
# Feature (binary)
# subject id.CFS subject 1                                          0
# subject id.CFS subject 2                                          0
# subject id.CFS subject 3                                          0
# subject id.CFS subject 4                                          0
# subject id.CFS subject 5                                          0
# subject id.CFS subject 6                                          0
# subject id.Control subject 1                                      0
# subject id.Control subject 2                                      0
# subject id.Control subject 3                                      0
# subject id.Control subject 4                                      0
# subject id.Control subject 5                                      0
# subject id.Control subject 6                                      0
# subject id.CFS subject 7                                          0
# subject id.CFS subject 8                                          0
# subject id.CFS subject 9                                          1
# subject id.CFS subject 10                                         0
# subject id.CFS subject 11                                         0
# subject id.CFS subject 12                                         0
# subject id.Control subject 7                                      0
# subject id.Control subject 8                                      0
# subject id.Control subject 9                                      0
# subject id.Control subject 10                                     0
# subject id.Control subject 11                                     0
# subject id.Control subject 12                                     0
# disease state.Chronic Fatigue Syndrome (CFS)                      1
# disease state.Control                                             0
#
#                                               PBMC genomic DNA_CFS10  \
# Feature (binary)
# subject id.CFS subject 1                                           0
# subject id.CFS subject 2                                           0
# subject id.CFS subject 3                                           0
# subject id.CFS subject 4                                           0
# subject id.CFS subject 5                                           0
# subject id.CFS subject 6                                           0
# subject id.Control subject 1                                       0
# subject id.Control subject 2                                       0
# subject id.Control subject 3                                       0
# subject id.Control subject 4                                       0
# subject id.Control subject 5                                       0
# subject id.Control subject 6                                       0
# subject id.CFS subject 7                                           0
# subject id.CFS subject 8                                           0
# subject id.CFS subject 9                                           0
# subject id.CFS subject 10                                          1
# subject id.CFS subject 11                                          0
# subject id.CFS subject 12                                          0
# subject id.Control subject 7                                       0
# subject id.Control subject 8                                       0
# subject id.Control subject 9                                       0
# subject id.Control subject 10                                      0
# subject id.Control subject 11                                      0
# subject id.Control subject 12                                      0
# disease state.Chronic Fatigue Syndrome (CFS)                       1
# disease state.Control                                              0
#
#                                               PBMC genomic DNA_CFS11  \
# Feature (binary)
# subject id.CFS subject 1                                           0
# subject id.CFS subject 2                                           0
# subject id.CFS subject 3                                           0
# subject id.CFS subject 4                                           0
# subject id.CFS subject 5                                           0
# subject id.CFS subject 6                                           0
# subject id.Control subject 1                                       0
# subject id.Control subject 2                                       0
# subject id.Control subject 3                                       0
# subject id.Control subject 4                                       0
# subject id.Control subject 5                                       0
# subject id.Control subject 6                                       0
# subject id.CFS subject 7                                           0
# subject id.CFS subject 8                                           0
# subject id.CFS subject 9                                           0
# subject id.CFS subject 10                                          0
# subject id.CFS subject 11                                          1
# subject id.CFS subject 12                                          0
# subject id.Control subject 7                                       0
# subject id.Control subject 8                                       0
# subject id.Control subject 9                                       0
# subject id.Control subject 10                                      0
# subject id.Control subject 11                                      0
# subject id.Control subject 12                                      0
# disease state.Chronic Fatigue Syndrome (CFS)                       1
# disease state.Control                                              0
#
#                                               PBMC genomic DNA_CFS12  \
# Feature (binary)
# subject id.CFS subject 1                                           0
# subject id.CFS subject 2                                           0
# subject id.CFS subject 3                                           0
# subject id.CFS subject 4                                           0
# subject id.CFS subject 5                                           0
# subject id.CFS subject 6                                           0
# subject id.Control subject 1                                       0
# subject id.Control subject 2                                       0
# subject id.Control subject 3                                       0
# subject id.Control subject 4                                       0
# subject id.Control subject 5                                       0
# subject id.Control subject 6                                       0
# subject id.CFS subject 7                                           0
# subject id.CFS subject 8                                           0
# subject id.CFS subject 9                                           0
# subject id.CFS subject 10                                          0
# subject id.CFS subject 11                                          0
# subject id.CFS subject 12                                          1
# subject id.Control subject 7                                       0
# subject id.Control subject 8                                       0
# subject id.Control subject 9                                       0
# subject id.Control subject 10                                      0
# subject id.Control subject 11                                      0
# subject id.Control subject 12                                      0
# disease state.Chronic Fatigue Syndrome (CFS)                       1
# disease state.Control                                              0
#
#                                               PBMC genomic DNA_Control7  \
# Feature (binary)
# subject id.CFS subject 1                                              0
# subject id.CFS subject 2                                              0
# subject id.CFS subject 3                                              0
# subject id.CFS subject 4                                              0
# subject id.CFS subject 5                                              0
# subject id.CFS subject 6                                              0
# subject id.Control subject 1                                          0
# subject id.Control subject 2                                          0
# subject id.Control subject 3                                          0
# subject id.Control subject 4                                          0
# subject id.Control subject 5                                          0
# subject id.Control subject 6                                          0
# subject id.CFS subject 7                                              0
# subject id.CFS subject 8                                              0
# subject id.CFS subject 9                                              0
# subject id.CFS subject 10                                             0
# subject id.CFS subject 11                                             0
# subject id.CFS subject 12                                             0
# subject id.Control subject 7                                          1
# subject id.Control subject 8                                          0
# subject id.Control subject 9                                          0
# subject id.Control subject 10                                         0
# subject id.Control subject 11                                         0
# subject id.Control subject 12                                         0
# disease state.Chronic Fatigue Syndrome (CFS)                          0
# disease state.Control                                                 1
#
#                                               PBMC genomic DNA_Control8  \
# Feature (binary)
# subject id.CFS subject 1                                              0
# subject id.CFS subject 2                                              0
# subject id.CFS subject 3                                              0
# subject id.CFS subject 4                                              0
# subject id.CFS subject 5                                              0
# subject id.CFS subject 6                                              0
# subject id.Control subject 1                                          0
# subject id.Control subject 2                                          0
# subject id.Control subject 3                                          0
# subject id.Control subject 4                                          0
# subject id.Control subject 5                                          0
# subject id.Control subject 6                                          0
# subject id.CFS subject 7                                              0
# subject id.CFS subject 8                                              0
# subject id.CFS subject 9                                              0
# subject id.CFS subject 10                                             0
# subject id.CFS subject 11                                             0
# subject id.CFS subject 12                                             0
# subject id.Control subject 7                                          0
# subject id.Control subject 8                                          1
# subject id.Control subject 9                                          0
# subject id.Control subject 10                                         0
# subject id.Control subject 11                                         0
# subject id.Control subject 12                                         0
# disease state.Chronic Fatigue Syndrome (CFS)                          0
# disease state.Control                                                 1
#
#                                               PBMC genomic DNA_Control9  \
# Feature (binary)
# subject id.CFS subject 1                                              0
# subject id.CFS subject 2                                              0
# subject id.CFS subject 3                                              0
# subject id.CFS subject 4                                              0
# subject id.CFS subject 5                                              0
# subject id.CFS subject 6                                              0
# subject id.Control subject 1                                          0
# subject id.Control subject 2                                          0
# subject id.Control subject 3                                          0
# subject id.Control subject 4                                          0
# subject id.Control subject 5                                          0
# subject id.Control subject 6                                          0
# subject id.CFS subject 7                                              0
# subject id.CFS subject 8                                              0
# subject id.CFS subject 9                                              0
# subject id.CFS subject 10                                             0
# subject id.CFS subject 11                                             0
# subject id.CFS subject 12                                             0
# subject id.Control subject 7                                          0
# subject id.Control subject 8                                          0
# subject id.Control subject 9                                          1
# subject id.Control subject 10                                         0
# subject id.Control subject 11                                         0
# subject id.Control subject 12                                         0
# disease state.Chronic Fatigue Syndrome (CFS)                          0
# disease state.Control                                                 1
#
#                                               PBMC genomic DNA_Control10  \
# Feature (binary)
# subject id.CFS subject 1                                               0
# subject id.CFS subject 2                                               0
# subject id.CFS subject 3                                               0
# subject id.CFS subject 4                                               0
# subject id.CFS subject 5                                               0
# subject id.CFS subject 6                                               0
# subject id.Control subject 1                                           0
# subject id.Control subject 2                                           0
# subject id.Control subject 3                                           0
# subject id.Control subject 4                                           0
# subject id.Control subject 5                                           0
# subject id.Control subject 6                                           0
# subject id.CFS subject 7                                               0
# subject id.CFS subject 8                                               0
# subject id.CFS subject 9                                               0
# subject id.CFS subject 10                                              0
# subject id.CFS subject 11                                              0
# subject id.CFS subject 12                                              0
# subject id.Control subject 7                                           0
# subject id.Control subject 8                                           0
# subject id.Control subject 9                                           0
# subject id.Control subject 10                                          1
# subject id.Control subject 11                                          0
# subject id.Control subject 12                                          0
# disease state.Chronic Fatigue Syndrome (CFS)                           0
# disease state.Control                                                  1
#
#                                               PBMC genomic DNA_Control11  \
# Feature (binary)
# subject id.CFS subject 1                                               0
# subject id.CFS subject 2                                               0
# subject id.CFS subject 3                                               0
# subject id.CFS subject 4                                               0
# subject id.CFS subject 5                                               0
# subject id.CFS subject 6                                               0
# subject id.Control subject 1                                           0
# subject id.Control subject 2                                           0
# subject id.Control subject 3                                           0
# subject id.Control subject 4                                           0
# subject id.Control subject 5                                           0
# subject id.Control subject 6                                           0
# subject id.CFS subject 7                                               0
# subject id.CFS subject 8                                               0
# subject id.CFS subject 9                                               0
# subject id.CFS subject 10                                              0
# subject id.CFS subject 11                                              0
# subject id.CFS subject 12                                              0
# subject id.Control subject 7                                           0
# subject id.Control subject 8                                           0
# subject id.Control subject 9                                           0
# subject id.Control subject 10                                          0
# subject id.Control subject 11                                          1
# subject id.Control subject 12                                          0
# disease state.Chronic Fatigue Syndrome (CFS)                           0
# disease state.Control                                                  1
#
#                                               PBMC genomic DNA_Control12
# Feature (binary)
# subject id.CFS subject 1                                               0
# subject id.CFS subject 2                                               0
# subject id.CFS subject 3                                               0
# subject id.CFS subject 4                                               0
# subject id.CFS subject 5                                               0
# subject id.CFS subject 6                                               0
# subject id.Control subject 1                                           0
# subject id.Control subject 2                                           0
# subject id.Control subject 3                                           0
# subject id.Control subject 4                                           0
# subject id.Control subject 5                                           0
# subject id.Control subject 6                                           0
# subject id.CFS subject 7                                               0
# subject id.CFS subject 8                                               0
# subject id.CFS subject 9                                               0
# subject id.CFS subject 10                                              0
# subject id.CFS subject 11                                              0
# subject id.CFS subject 12                                              0
# subject id.Control subject 7                                           0
# subject id.Control subject 8                                           0
# subject id.Control subject 9                                           0
# subject id.Control subject 10                                          0
# subject id.Control subject 11                                          0
# subject id.Control subject 12                                          1
# disease state.Chronic Fatigue Syndrome (CFS)                           0
# disease state.Control                                                  1
#
# [26 rows x 24 columns]

# %%
gene_x_sample = _x_sample_[3]

gene_x_sample.to_csv(path_template.format("gene"), sep="\t")

gene_x_sample
# Out:
#           PBMC genomic DNA_CFS1  PBMC genomic DNA_CFS2  PBMC genomic DNA_CFS3  \
# Gene
# A1BG                   0.606930               0.517600               0.634525
# A1BG-AS1               0.322765               0.299545               0.307850
# A1CF                   0.838470               0.829080               0.858160
# A2M                    0.451520               0.500430               0.577690
# A2ML1                  0.614895               0.716785               0.768880
# ...                         ...                    ...                    ...
# ZYG11A                 0.220070               0.251920               0.310140
# ZYG11B                 0.897670               0.860910               0.904950
# ZYX                    0.598340               0.612250               0.615920
# ZZEF1                  0.644770               0.657280               0.745700
# ZZZ3                   0.686710               0.683625               0.707100
#
#           PBMC genomic DNA_CFS4  PBMC genomic DNA_CFS5  PBMC genomic DNA_CFS6  \
# Gene
# A1BG                   0.701570               0.626285               0.705480
# A1BG-AS1               0.305910               0.340580               0.360850
# A1CF                   0.846640               0.822610               0.864050
# A2M                    0.527570               0.514230               0.497130
# A2ML1                  0.674325               0.751895               0.729165
# ...                         ...                    ...                    ...
# ZYG11A                 0.318110               0.312280               0.378310
# ZYG11B                 0.891240               0.899170               0.908370
# ZYX                    0.680370               0.621620               0.613220
# ZZEF1                  0.706910               0.713110               0.720060
# ZZZ3                   0.683130               0.691795               0.717315
#
#           PBMC genomic DNA_Control1  PBMC genomic DNA_Control2  \
# Gene
# A1BG                       0.647650                   0.653085
# A1BG-AS1                   0.345705                   0.291185
# A1CF                       0.823190                   0.845670
# A2M                        0.460450                   0.403540
# A2ML1                      0.626640                   0.663295
# ...                             ...                        ...
# ZYG11A                     0.225780                   0.280930
# ZYG11B                     0.891450                   0.898900
# ZYX                        0.651340                   0.644590
# ZZEF1                      0.657720                   0.690660
# ZZZ3                       0.685575                   0.699820
#
#           PBMC genomic DNA_Control3  PBMC genomic DNA_Control4  ...  \
# Gene                                                            ...
# A1BG                       0.641760                   0.703755  ...
# A1BG-AS1                   0.258035                   0.323490  ...
# A1CF                       0.819110                   0.849990  ...
# A2M                        0.432380                   0.447220  ...
# A2ML1                      0.724850                   0.683435  ...
# ...                             ...                        ...  ...
# ZYG11A                     0.280770                   0.277820  ...
# ZYG11B                     0.897750                   0.897520  ...
# ZYX                        0.689930                   0.703890  ...
# ZZEF1                      0.722710                   0.722840  ...
# ZZZ3                       0.642290                   0.683775  ...
#
#           PBMC genomic DNA_CFS9  PBMC genomic DNA_CFS10  \
# Gene
# A1BG                   0.564815                0.661010
# A1BG-AS1               0.281965                0.255970
# A1CF                   0.840560                0.820530
# A2M                    0.429440                0.391870
# A2ML1                  0.729585                0.695200
# ...                         ...                     ...
# ZYG11A                 0.362790                0.341890
# ZYG11B                 0.880190                0.890040
# ZYX                    0.639120                0.669110
# ZZEF1                  0.659700                0.718200
# ZZZ3                   0.681085                0.628725
#
#           PBMC genomic DNA_CFS11  PBMC genomic DNA_CFS12  \
# Gene
# A1BG                    0.644785                0.648275
# A1BG-AS1                0.326325                0.384450
# A1CF                    0.836140                0.810770
# A2M                     0.502930                0.498510
# A2ML1                   0.758185                0.701725
# ...                          ...                     ...
# ZYG11A                  0.358740                0.286220
# ZYG11B                  0.892500                0.890530
# ZYX                     0.617140                0.707750
# ZZEF1                   0.723370                0.730900
# ZZZ3                    0.695650                0.665485
#
#           PBMC genomic DNA_Control7  PBMC genomic DNA_Control8  \
# Gene
# A1BG                       0.630285                   0.682005
# A1BG-AS1                   0.347975                   0.326740
# A1CF                       0.831130                   0.828550
# A2M                        0.488830                   0.388410
# A2ML1                      0.622095                   0.656115
# ...                             ...                        ...
# ZYG11A                     0.285940                   0.296430
# ZYG11B                     0.882180                   0.892080
# ZYX                        0.639760                   0.594020
# ZZEF1                      0.671870                   0.696940
# ZZZ3                       0.702795                   0.660980
#
#           PBMC genomic DNA_Control9  PBMC genomic DNA_Control10  \
# Gene
# A1BG                       0.615495                    0.625865
# A1BG-AS1                   0.335440                    0.386190
# A1CF                       0.823300                    0.858110
# A2M                        0.467160                    0.416500
# A2ML1                      0.667280                    0.683210
# ...                             ...                         ...
# ZYG11A                     0.280310                    0.260580
# ZYG11B                     0.894880                    0.898010
# ZYX                        0.671450                    0.682170
# ZZEF1                      0.738070                    0.690950
# ZZZ3                       0.618205                    0.675265
#
#           PBMC genomic DNA_Control11  PBMC genomic DNA_Control12
# Gene
# A1BG                        0.677970                    0.589765
# A1BG-AS1                    0.364775                    0.319300
# A1CF                        0.853010                    0.829740
# A2M                         0.494450                    0.513080
# A2ML1                       0.613745                    0.754370
# ...                              ...                         ...
# ZYG11A                      0.277170                    0.380650
# ZYG11B                      0.882980                    0.890210
# ZYX                         0.628610                    0.632600
# ZZEF1                       0.700380                    0.703240
# ZZZ3                        0.737550                    0.716315
#
# [18674 rows x 24 columns]
