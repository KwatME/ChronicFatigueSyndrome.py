# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

import kraft

# %%
SETTING = kraft.json.read("setting.json")

# %% [markdown]
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE67311

# %%
_x_samples = kraft.geo.get_gse(
    "GSE67311", SETTING["data_directory_path"], overwrite=SETTING["overwrite"]
)
# Out:
# /media/kwat/CarrotCake/garden/data/chronic_fatigue_syndrome//GSE67311_family.soft.gz exists.
# --------------------------------------------------------------------------------
#                                              C001                      C002
# Feature
# Sample_geo_accession                   GSM1644447                GSM1644448
# Sample_status               Public on Feb 01 2016     Public on Feb 01 2016
# Sample_submission_date                Mar 26 2015               Mar 26 2015
# Sample_last_update_date               Feb 01 2016               Feb 01 2016
# Sample_type                                   RNA                       RNA
# Sample_channel_count                            1                         1
# Sample_source_name_ch1   Peripheral Blood_Control  Peripheral Blood_Control
# Sample_organism_ch1                  Homo sapiens              Homo sapiens
# (31, 142)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
#                                C001  C002
# Feature
# chronic fatigue syndrome: No      1     1
# bipolar disorder: -               0     0
# chronic fatigue syndrome: -       0     0
# chronic fatigue syndrome: Yes     0     0
# (4, 142)
# --------------------------------------------------------------------------------
#
#
# GPL11532
# GB_LIST
# SPOT_ID
# seqname
# RANGE_GB
# RANGE_STRAND
# RANGE_START
# RANGE_STOP
# total_probes
# > gene_assignment <
# mrna_assignment
# category
# 33297 keys ==> 20255 unique values
# (33297, 142)
# Collapsing...
# (20254, 142)
# --------------------------------------------------------------------------------
#             C001      C002
# Gene
# A1BG     9.18319   8.94812
# A1CF    11.44940  11.71730
# A2LD1    8.03428   8.00332
# A2M      3.19828   2.38255
# A2ML1    2.95199   2.90345
# A4GALT   7.14785   6.94445
# A4GNT    4.46222   4.47233
# AAA1     3.95541   4.12755
# (20254, 142)
# --------------------------------------------------------------------------------

# %%
binary_feature_x_sample = _x_samples[2]

binary_feature_x_sample
# Out:
#                                C001  C002  C003  C004  C005  C006  C007  C009  \
# Feature
# chronic fatigue syndrome: No      1     1     1     1     1     1     1     1
# bipolar disorder: -               0     0     0     0     0     0     0     0
# chronic fatigue syndrome: -       0     0     0     0     0     0     0     0
# chronic fatigue syndrome: Yes     0     0     0     0     0     0     0     0
#
#                                C009_2  C010  ...  F060  F061  F064  F065  \
# Feature                                      ...
# chronic fatigue syndrome: No        1     1  ...     1     1     1     0
# bipolar disorder: -                 0     0  ...     0     0     0     0
# chronic fatigue syndrome: -         0     0  ...     0     0     0     0
# chronic fatigue syndrome: Yes       0     0  ...     0     0     0     1
#
#                                F066  F067  F067_2  F068  F069  F070
# Feature
# chronic fatigue syndrome: No      0     1       0     1     1     1
# bipolar disorder: -               0     0       0     0     0     0
# chronic fatigue syndrome: -       0     0       1     0     0     0
# chronic fatigue syndrome: Yes     1     0       0     0     0     0
#
# [4 rows x 142 columns]

# %%
gene_x_sample = _x_samples[3]

gene_x_sample
# Out:
#                 C001      C002      C003       C004       C005      C006  \
# Gene
# A1BG        9.183190   8.94812   9.16345   9.234850   9.171450   8.92876
