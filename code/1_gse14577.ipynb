# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

import kraft

# %%
SETTING = kraft.json.read("setting.json")

# %% [markdown]
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE14577

# %%
_x_samples = kraft.geo.get_gse(
    "GSE14577", SETTING["data_directory_path"], overwrite=False
)
# Out:
# ../data//GSE14577_family.soft.gz exists.
# Named 9279 genes.
# Named 138 genes.
# ================================================================================
# (31, 30)
# --------------------------------------------------------------------------------
# Sample_title         control patient 1, chip A control patient 2, chip A
# Feature
# Sample_geo_accession                 GSM364557                 GSM364558
# Sample_status            Public on Jan 27 2009     Public on Jan 27 2009
# ================================================================================
# (8956, 15)
# --------------------------------------------------------------------------------
#        control patient 1, chip A  control patient 2, chip A
# GPL96
# A1CF                    5.960355                   6.037794
# A2M                     5.470636                   5.287431
# ================================================================================
# (137, 15)
# --------------------------------------------------------------------------------
#        control patient 1, chip B  control patient 2, chip B
# GPL97
# ABCF1                   9.691783                   9.751319
# ABCG8                   6.262865                   6.044453

# %%
feature_x_sample = _x_samples[0]

for row_name, row in feature_x_sample.iterrows():

    n_unique = row.unique().size

    if 1 < n_unique != row.size:

        print("=" * 80)

        print(row.value_counts())
# Out:
# ================================================================================
# PBMC, CFS        16
# PBMC, control    14
# Name: Sample_source_name_ch1, dtype: int64
# ================================================================================
# Male, post-infectious CFS patient    16
# Male, healthy normal control         14
# Name: Sample_characteristics_ch1, dtype: int64
# ================================================================================
# GPL97    15
# GPL96    15
# Name: Sample_platform_id, dtype: int64
# ================================================================================
# 22645    15
# 22283    15
# Name: Sample_data_row_count, dtype: int64

# %%
continuous, binary = kraft.feature_x_sample.separate_type(
    feature_x_sample.loc[
        (
            "Sample_characteristics_" in label
            for label in feature_x_sample.index.to_numpy()
        ),
        :,
    ]
)

# %%
continuous
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
binary
# Out:
# Sample_title                                        control patient 1, chip A  \
# Feature
# (Sample_characteristics_ch1) Male, healthy norm...                          1
# (Sample_characteristics_ch1) Male, post-infecti...                          0
#
# Sample_title                                        control patient 2, chip A  \
# Feature
# (Sample_characteristics_ch1) Male, healthy norm...                          1
# (Sample_characteristics_ch1) Male, post-infecti...                          0
#
# Sample_title                                        control patient 3, chip A  \
# Feature
# (Sample_characteristics_ch1) Male, healthy norm...                          1
# (Sample_characteristics_ch1) Male, post-infecti...                          0
#
# Sample_title                                        control patient 5, chip A  \
# Feature
# (Sample_characteristics_ch1) Male, healthy norm...                          1
# (Sample_characteristics_ch1) Male, post-infecti...                          0
#
# Sample_title                                        control patient 6, chip A  \
# Feature
# (Sample_characteristics_ch1) Male, healthy norm...                          1
# (Sample_characteristics_ch1) Male, post-infecti...                          0
#
# Sample_title                                        control patient 7, chip A  \
# Feature
# (Sample_characteristics_ch1) Male, healthy norm...                          1
# (Sample_characteristics_ch1) Male, post-infecti...                          0
#
# Sample_title                                        control patient 8, chip A  \
# Feature
# (Sample_characteristics_ch1) Male, healthy norm...                          1
# (Sample_characteristics_ch1) Male, post-infecti...                          0
#
# Sample_title                                        CFS patient 2, chip A  \
# Feature
# (Sample_characteristics_ch1) Male, healthy norm...                      0
# (Sample_characteristics_ch1) Male, post-infecti...                      1
#
# Sample_title                                        CFS patient 3, chip A  \
# Feature
# (Sample_characteristics_ch1) Male, healthy norm...                      0
# (Sample_characteristics_ch1) Male, post-infecti...                      1
#
# Sample_title                                        CFS patient 4, chip A  \
# Feature
# (Sample_characteristics_ch1) Male, healthy norm...                      0
# (Sample_characteristics_ch1) Male, post-infecti...                      1
#
# Sample_title                                        ...  \
# Feature                                             ...
# (Sample_characteristics_ch1) Male, healthy norm...  ...
# (Sample_characteristics_ch1) Male, post-infecti...  ...
#
# Sample_title                                        control patient 7, chip B  \
# Feature
# (Sample_characteristics_ch1) Male, healthy norm...                          1
# (Sample_characteristics_ch1) Male, post-infecti...                          0
#
# Sample_title                                        control patient 8, chip B  \
# Feature
# (Sample_characteristics_ch1) Male, healthy norm...                          1
# (Sample_characteristics_ch1) Male, post-infecti...                          0
#
# Sample_title                                        CFS patient 2, chip B  \
# Feature
# (Sample_characteristics_ch1) Male, healthy norm...                      0
# (Sample_characteristics_ch1) Male, post-infecti...                      1
#
# Sample_title                                        CFS patient 3, chip B  \
# Feature
# (Sample_characteristics_ch1) Male, healthy norm...                      0
# (Sample_characteristics_ch1) Male, post-infecti...                      1
#
# Sample_title                                        CFS patient 4, chip B  \
# Feature
# (Sample_characteristics_ch1) Male, healthy norm...                      0
# (Sample_characteristics_ch1) Male, post-infecti...                      1
#
# Sample_title                                        CFS patient 5, chip B  \
# Feature
# (Sample_characteristics_ch1) Male, healthy norm...                      0
# (Sample_characteristics_ch1) Male, post-infecti...                      1
#
# Sample_title                                        CFS patient 6, chip B  \
# Feature
# (Sample_characteristics_ch1) Male, healthy norm...                      0
# (Sample_characteristics_ch1) Male, post-infecti...                      1
#
# Sample_title                                        CFS patient 7, chip B  \
# Feature
# (Sample_characteristics_ch1) Male, healthy norm...                      0
# (Sample_characteristics_ch1) Male, post-infecti...                      1
#
# Sample_title                                        CFS patient 8, chip B  \
# Feature
# (Sample_characteristics_ch1) Male, healthy norm...                      0
# (Sample_characteristics_ch1) Male, post-infecti...                      1
#
# Sample_title                                        CFS patient 9, chip B
# Feature
# (Sample_characteristics_ch1) Male, healthy norm...                      0
# (Sample_characteristics_ch1) Male, post-infecti...                      1
#
# [2 rows x 30 columns]

# %%
gene_x_sample = _x_samples[1]

gene_x_sample
# Out:
#         control patient 1, chip A  control patient 2, chip A  \
# GPL96
# A1CF                     5.960355                   6.037794
# A2M                      5.470636                   5.287431
# A4GALT                   6.087496                   6.235389
# A4GNT                    6.327743                   5.907849
# AAAS                     7.759847                   7.490575
# ...                           ...                        ...
# ZWILCH                   5.071287                   5.235246
# ZWINT                    7.407082                   7.590281
# ZXDC                     8.736023                   9.154528
# ZYX                      8.315094                   8.386980
# ZZEF1                    6.072610                   6.219678
#
#         control patient 3, chip A  control patient 5, chip A  \
# GPL96
# A1CF                     6.027788                   5.975468
# A2M                      5.651004                   5.608455
# A4GALT                   6.291484                   6.559245
# A4GNT                    6.039503                   6.046954
# AAAS                     7.788027                   7.786308
# ...                           ...                        ...
# ZWILCH                   5.060296                   5.127347
# ZWINT                    7.559464                   6.943888
# ZXDC                     8.899570                   8.065897
# ZYX                      8.097152                   8.330138
# ZZEF1                    6.345610                   6.267620
#
#         control patient 6, chip A  control patient 7, chip A  \
# GPL96
# A1CF                     5.600582                   5.712912
# A2M                      5.445385                   5.397245
# A4GALT                   6.235389                   6.061005
# A4GNT                    5.956771                   5.906553
# AAAS                     7.826915                   7.792568
# ...                           ...                        ...
# ZWILCH                   5.330361                   5.413492
# ZWINT                    7.638654                   7.436485
# ZXDC                     8.696818                   8.553543
# ZYX                      8.252703                   8.263036
# ZZEF1                    6.232244                   6.377125
#
#         control patient 8, chip A  CFS patient 2, chip A  \
# GPL96
# A1CF                     5.921344               5.549905
# A2M                      5.440019               5.335718
# A4GALT                   6.098479               6.237428
# A4GNT                    6.006394               5.753541
# AAAS                     7.827768               7.450379
# ...                           ...                    ...
# ZWILCH                   4.894070               5.071287
# ZWINT                    7.294520               7.317293
# ZXDC                     8.498471               9.062409
# ZYX                      8.634703               8.699038
# ZZEF1                    6.276750               6.303406
#
#         CFS patient 3, chip A  CFS patient 4, chip A  CFS patient 5, chip A  \
# GPL96
# A1CF                 5.564409               5.172576               5.639225
# A2M                  5.212536               5.144631               5.193750
# A4GALT               6.235389               6.235389               6.191773
# A4GNT                5.878988               5.619954               6.004769
# AAAS                 7.786308               7.759876               7.734136
# ...                       ...                    ...                    ...
# ZWILCH               5.071287               4.950539               5.221612
# ZWINT                7.677421               7.774059               8.167518
# ZXDC                 9.235292               8.988271               8.712467
# ZYX                  8.550971               8.768634               8.839771
# ZZEF1                6.251419               6.236814               6.082131
#
#         CFS patient 6, chip A  CFS patient 7, chip A  CFS patient 8, chip A  \
# GPL96
# A1CF                 5.504256               5.411318               5.712912
# A2M                  5.030857               5.152392               5.306540
# A4GALT               6.098479               6.279517               6.202890
# A4GNT                5.985470               5.873349               5.844911
# AAAS                 7.820736               7.937262               7.786308
# ...                       ...                    ...                    ...
# ZWILCH               4.733295               4.425830               4.928456
# ZWINT                7.318815               7.623154               7.547155
# ZXDC                 8.745871               8.955446               8.923578
# ZYX                  8.768440               8.955374               8.348985
# ZZEF1                6.016337               6.425755               6.142697
#
#         CFS patient 9, chip A
# GPL96
# A1CF                 5.568356
# A2M                  5.241848
# A4GALT               6.235389
# A4GNT                5.929213
# AAAS                 7.866721
# ...                       ...
# ZWILCH               5.103409
# ZWINT                7.560832
# ZXDC                 9.264359
# ZYX                  8.666103
# ZZEF1                6.264262
#
# [8956 rows x 15 columns]
